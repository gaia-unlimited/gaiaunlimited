# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Getting started

# %%
import numpy as np
import healpy as hp

# %%
from gaiasf.selectionfunctions import DR2SelectionFunction, DR3SelectionFunction
from gaiasf.utils import get_healpix_centers

# %%
dr2 = DR2SelectionFunction()
dr3 = DR3SelectionFunction()

# %%
cc = get_healpix_centers(5)
gmag = np.ones_like(cc) * 21
p2 = dr2.query(cc, gmag)
p3 = dr3.query(cc, gmag)

# %%
hp.mollview(p2)

# %%
hp.mollview(p3)

# %%
hp.mollview(p3/p2, max=3.5);
